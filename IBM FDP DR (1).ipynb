# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='IBL7geQ8zphH9EMu5T8KVCD06VOXncr1vjctZPTbk_i_',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'ibmfdp-donotdelete-pr-rfb0ewlu41m8jx'
object_key = 'kaggle (1).zip'

streaming_body_3 = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/

# %%
# !pip install -q kaggle

# %%
# !mkdir ~/.kaggle # creating a kaggle directory

import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='ulxH3FIxpECPVLNt6xMtA_k49JAEaKapgC-G4uDPk5Eo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'ibmfdp-donotdelete-pr-r2osfxmlnq8za8'
object_key = 'kaggle (1).zip'

streaming_body_7 = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/



import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='ulxH3FIxpECPVLNt6xMtA_k49JAEaKapgC-G4uDPk5Eo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'ibmfdp-donotdelete-pr-r2osfxmlnq8za8'
object_key = 'kaggle (1).zip'

streaming_body_6 = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/



import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='ulxH3FIxpECPVLNt6xMtA_k49JAEaKapgC-G4uDPk5Eo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'ibmfdp-donotdelete-pr-r2osfxmlnq8za8'
object_key = 'kaggle (1).zip'

streaming_body_5 = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/



import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='ulxH3FIxpECPVLNt6xMtA_k49JAEaKapgC-G4uDPk5Eo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'ibmfdp-donotdelete-pr-r2osfxmlnq8za8'
object_key = 'kaggle (1).zip'

streaming_body_4 = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
from io import BytesIO
import zipfile
unzip=zipfile.ZipFile(BytesIO(streaming_body_4.read()),'r')
file_paths=unzip.namelist()
for path in file_paths:
    unzip.extract(path)

# %%
ls
# Out:
# diabetic-retinopathy-level-detection.zip  kaggle.json

# %%
cd /home/wsuser/work/kaggle
# Out:
# /home/wsuser/work/kaggle

# %%
ls
# Out:
# diabetic-retinopathy-level-detection.zip  kaggle.json

# %%
# !cp kaggle.json ~/.kaggle/  # copying json file to folder

# %%
# !chmod 600 ~/.kaggle/kaggle.json  # changing the permissions to json

# %%
# !kaggle datasets download -d arbethi/diabetic-retinopathy-level-detection
# Out:
# Downloading diabetic-retinopathy-level-detection.zip to /home/wsuser/work/kaggle
# ... resuming from 0 bytes (10367856463 bytes left) ...
# 100%|██████████████████████████████████████▉| 9.64G/9.66G [00:43<00:00, 313MB/s]
# 100%|███████████████████████████████████████| 9.66G/9.66G [00:43<00:00, 240MB/s]

# %%
# !unzip diabetic-retinopathy-level-detection.zip
# Out:
# Archive:  diabetic-retinopathy-level-detection.zip
# replace inception-diabetic.h5? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.applications.xception import Xception, preprocess_input
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/home/wsuser/work/kaggle'

# %%
ls
# Out:
#  diabetic-retinopathy-level-detection.zip   kaggle.json
#  inception-diabetic.h5                     'preprocessed dataset'/

# %%
cd /home/wsuser/work/kaggle/preprocessed dataset/preprocessed dataset
# Out:
# /home/wsuser/work/kaggle/preprocessed dataset/preprocessed dataset

# %%
imageSize = [299, 299]

trainPath = r"/home/wsuser/work/kaggle/preprocessed dataset/preprocessed dataset/training"

testPath = r"/home/wsuser/work/kaggle/preprocessed dataset/preprocessed dataset/testing"

# %%
xception = Xception(input_shape=imageSize + [3], weights='imagenet',include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step

# %%
# don't train existing weights
for layer in xception.layers:
    layer.trainable = False

# %%
# our layers - you can add more if you want
x = Flatten()(xception.output)

# %%
prediction = Dense(5, activation='softmax')(x)

# %%
# create a model object
model = Model(inputs=xception.input, outputs=prediction)

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
pwd
# Out:
# '/home/wsuser/work/kaggle/preprocessed dataset/preprocessed dataset'

# %%
ls
# Out:
# testing/  training/

# %%
training_set = train_datagen.flow_from_directory(r'/home/wsuser/work/kaggle/preprocessed dataset/preprocessed dataset/training',
                                                 target_size = (299, 299),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(r'/home/wsuser/work/kaggle/preprocessed dataset/preprocessed dataset/testing',
                                            target_size = (299, 299),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 3662 images belonging to 5 classes.
# Found 734 images belonging to 5 classes.

# %%
# fit the model
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=5,
  steps_per_epoch=len(training_set)//32,
  validation_steps=len(test_set)//32
)

# %%
model.save('IBMDR.h5')

# %%
# !tar -zcvf image-classification-model_new.tgz IBMDR.h5

# %%
ls -1
# Out:
# IBMDR.h5
# image-classification-model_new.tgz
# testing/
# training/

# %% [markdown]
# # IBM Deployment

# %%
# !pip install watson-machine-learning-client --upgrade
# Out:
# Requirement already satisfied: watson-machine-learning-client in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (1.0.391)
# Requirement already satisfied: requests in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from watson-machine-learning-client) (2.31.0)
# Requirement already satisfied: urllib3 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from watson-machine-learning-client) (1.26.18)
# Requirement already satisfied: pandas in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from watson-machine-learning-client) (1.5.3)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from watson-machine-learning-client) (2023.11.17)
# Requirement already satisfied: tqdm in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from watson-machine-learning-client) (4.65.0)
# Requirement already satisfied: lomond in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from watson-machine-learning-client) (0.3.3)
# Requirement already satisfied: tabulate in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from watson-machine-learning-client) (0.8.10)
# Requirement already satisfied: ibm-cos-sdk in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from watson-machine-learning-client) (2.12.0)
# Requirement already satisfied: boto3 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from watson-machine-learning-client) (1.24.28)
# Requirement already satisfied: botocore<1.28.0,>=1.27.28 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from boto3->watson-machine-learning-client) (1.27.59)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from boto3->watson-machine-learning-client) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from boto3->watson-machine-learning-client) (0.6.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.12.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-cos-sdk->watson-machine-learning-client) (2.12.0)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.12.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-cos-sdk->watson-machine-learning-client) (2.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-cos-sdk-core==2.12.0->ibm-cos-sdk->watson-machine-learning-client) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from requests->watson-machine-learning-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from requests->watson-machine-learning-client) (3.4)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from lomond->watson-machine-learning-client) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from pandas->watson-machine-learning-client) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from pandas->watson-machine-learning-client) (1.23.5)

# %%
from ibm_watson_machine_learning import APIClient
wml_credentials={"url":"https://us-south.ml.cloud.ibm.com",
                "apikey":"2tkrW5DQSRCC-hHzXqooUCikEbzcgSVr4OFzZwMynJQQ"}
client = APIClient(wml_credentials)

# %%
client = APIClient(wml_credentials)

# %%
client.spaces.list()
# Out:
# Note: 'limit' is not provided. Only first 50 records will be displayed if the number of records exceed 50
# ------------------------------------  -------  ------------------------
# ID                                    NAME     CREATED
# 45b4c770-09cb-4988-81fb-80e84dfb4fe2  IBM_FDP  2024-01-05T13:42:11.428Z
# ------------------------------------  -------  ------------------------
#                                      ID     NAME                   CREATED
# 0  45b4c770-09cb-4988-81fb-80e84dfb4fe2  IBM_FDP  2024-01-05T13:42:11.428Z

# %%
space_uid="45b4c770-09cb-4988-81fb-80e84dfb4fe2"

# %%
client.set.default_space(space_uid)
# Out:
# 'SUCCESS'

# %%
client.software_specifications.list(100)
# Out:
# -----------------------------  ------------------------------------  ----  ------------  --------------------------
# NAME                           ID                                    TYPE  STATE         REPLACEMENT
# default_py3.6                  0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base  retired       runtime-22.2-py3.10
# autoai-ts_rt23.1-py3.10        01ce9391-1a79-5a33-94fb-2e134337f314  base  supported
# kernel-spark3.2-scala2.12      020d69ce-7ac1-5e68-ac1a-31189867356a  base  retired
# pytorch-onnx_1.3-py3.7-edt     069ea134-3346-5748-b513-49120e15d288  base  retired
# tensorflow_rt23.1-py3.10       079a91e0-245f-5269-8926-3c20b28f37dc  base  supported
# scikit-learn_0.20-py3.6        09c5a1d0-9c1e-4473-a344-eb7b665ff687  base  retired       runtime-22.2-py3.10
# spark-mllib_3.0-scala_2.12     09f4cff0-90a7-5899-b9ed-1ef348aebdee  base  retired
# pytorch-onnx_rt22.1-py3.9      0b848dd4-e681-5599-be41-b5f6fccc6471  base  retired       pytorch-onnx_rt22.2-py3.10
# ai-function_0.1-py3.6          0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base  retired       runtime-22.2-py3.10
# shiny-r3.6                     0e6e79df-875e-4f24-8ae9-62dcc2148306  base  retired
# tensorflow_2.4-py3.7-horovod   1092590a-307d-563d-9b62-4eb7d64b3f22  base  retired       tensorflow_rt22.2-py3.10
# pytorch_1.1-py3.6              10ac12d6-6b30-4ccd-8392-3e922c096a92  base  retired       runtime-22.2-py3.10
# tensorflow_1.15-py3.6-ddl      111e41b3-de2d-5422-a4d6-bf776828c4b7  base  retired
# autoai-kb_rt22.2-py3.10        125b6d9a-5b1f-5e8d-972a-b251688ccf40  base  supported     autoai-kb_rt23.1-py3.10
# watsonx-textgen-fm-1.0         129aec82-7e65-5c78-b812-4c0a74b916f5  base  not_provided
# runtime-22.1-py3.9             12b83a17-24d8-5082-900f-0ab31fbfd3cb  base  retired       runtime-22.2-py3.10
# masking-flows-spark            13666829-5570-53a7-927b-52d42a101d93  base  not_provided
# kernel-spark3.3-py3.10         147e6777-ccd1-5886-8571-5356abc20839  base  not_provided
# scikit-learn_0.22-py3.6        154010fa-5b3b-4ac1-82af-4d5ee5abbc85  base  retired       runtime-22.2-py3.10
# pytorch-onnx_rt23.1-py3.10     195067e6-4c5e-5fab-8bd0-e7623a88b4d3  base  supported
# default_r3.6                   1b70aec3-ab34-4b87-8aa0-a4a3c8296a36  base  retired
# pytorch-onnx_1.3-py3.6         1bc6029a-cc97-56da-b8e0-39c3880dbbe7  base  retired       runtime-22.2-py3.10
# kernel-spark3.3-r3.6           1c9e5454-f216-59dd-a20e-474a5cdf5988  base  retired
# tensorflow_2.1-py3.6           1eb25b84-d6ed-5dde-b6a5-3fbdf1665666  base  retired       runtime-22.2-py3.10
# spark-mllib_3.2                20047f72-0a98-58c7-9ff5-a77b012eb8f5  base  retired       spark-mllib_3.3
# tensorflow_2.4-py3.8-horovod   217c16f6-178f-56bf-824a-b19f20564c49  base  retired       tensorflow_rt22.2-py3.10
# runtime-22.1-py3.9-cuda        26215f05-08c3-5a41-a1b0-da66306ce658  base  retired       runtime-22.2-py3.10-cuda
# do_py3.8                       295addb5-9ef9-547e-9bf4-92ae3563e720  base  retired
# autoai-ts_3.8-py3.8            2aa0c932-798f-5ae9-abd6-15e0c2402fb5  base  retired       autoai-ts_rt22.2-py3.10
# tensorflow_1.15-py3.6          2b73a275-7cbf-420b-a912-eae7f436e0bc  base  retired       runtime-22.2-py3.10
# kernel-spark3.3-py3.9          2b7961e2-e3b1-5a8c-a491-482c8368839a  base  retired
# pytorch_1.2-py3.6              2c8ef57d-2687-4b7d-acce-01f94976dac1  base  retired       runtime-22.2-py3.10
# spark-mllib_2.3                2e51f700-bca0-4b0d-88dc-5c6791338875  base  retired       spark-mllib_3.3
# pytorch-onnx_1.1-py3.6-edt     32983cea-3f32-4400-8965-dde874a8d67e  base  retired       runtime-22.2-py3.10
# runtime-23.1-py3.10            336b29df-e0e1-5e7d-b6a5-f6ab722625b2  base  supported
# spark-mllib_3.0-py37           36507ebe-8770-55ba-ab2a-eafe787600e9  base  retired       spark-mllib_3.3
# spark-mllib_2.4                390d21f8-e58b-4fac-9c55-d7ceda621326  base  retired       spark-mllib_3.3
# autoai-ts_rt22.2-py3.10        396b2e83-0953-5b86-9a55-7ce1628a406f  base  supported     autoai-ts_rt23.1-py3.10
# xgboost_0.82-py3.6             39e31acd-5f30-41dc-ae44-60233c80306e  base  retired       runtime-22.2-py3.10
# pytorch-onnx_1.2-py3.6-edt     40589d0e-7019-4e28-8daa-fb03b6f4fe12  base  retired       runtime-22.2-py3.10
# pytorch-onnx_rt22.2-py3.10     40e73f55-783a-5535-b3fa-0c8b94291431  base  supported     pytorch-onnx_rt23.1-py3.10
# default_r36py38                41c247d3-45f8-5a71-b065-8580229facf0  base  retired
# autoai-ts_rt22.1-py3.9         4269d26e-07ba-5d40-8f66-2d495b0c71f7  base  retired       autoai-ts_rt22.2-py3.10
# autoai-obm_3.0                 42b92e18-d9ab-567f-988a-4240ba1ed5f7  base  retired       autoai-obm_3.2
# pmml-3.0_4.3                   493bcb95-16f1-5bc5-bee8-81b8af80e9c7  base  not_provided
# spark-mllib_2.4-r_3.6          49403dff-92e9-4c87-a3d7-a42d0021c095  base  retired       spark-mllib_3.3
# xgboost_0.90-py3.6             4ff8d6c2-1343-4c18-85e1-689c965304d3  base  retired       runtime-22.2-py3.10
# pytorch-onnx_1.1-py3.6         50f95b2a-bc16-43bb-bc94-b0bed208c60b  base  retired       runtime-22.2-py3.10
# autoai-ts_3.9-py3.8            52c57136-80fa-572e-8728-a5e7cbb42cde  base  retired       autoai-ts_rt22.2-py3.10
# spark-mllib_2.4-scala_2.11     55a70f99-7320-4be5-9fb9-9edb5a443af5  base  retired       spark-mllib_3.3
# spark-mllib_3.0                5c1b0ca2-4977-5c2e-9439-ffd44ea8ffe9  base  retired       spark-mllib_3.3
# autoai-obm_2.0                 5c2e37fa-80b8-5e77-840f-d912469614ee  base  retired       autoai-obm_3.2
# spss-modeler_18.1              5c3cad7e-507f-4b2a-a9a3-ab53a21dee8b  base  not_provided
# cuda-py3.8                     5d3232bf-c86b-5df4-a2cd-7bb870a1cd4e  base  retired
# runtime-22.2-py3.10-xc         5e8cddff-db4a-5a6a-b8aa-2d4af9864dab  base  not_provided
# autoai-kb_3.1-py3.7            632d4b22-10aa-5180-88f0-f52dfb6444d7  base  retired       autoai-kb_rt22.2-py3.10
# pytorch-onnx_1.7-py3.8         634d3cdc-b562-5bf9-a2d4-ea90a478456b  base  retired       pytorch-onnx_rt22.2-py3.10
# kernel-spark3.3-r4.2           65691379-8334-5b81-9d22-a9b77b3c2f8b  base  not_provided
# spark-mllib_2.3-r_3.6          6586b9e3-ccd6-4f92-900f-0f8cb2bd6f0c  base  retired
# tensorflow_2.4-py3.7           65e171d7-72d1-55d9-8ebb-f813d620c9bb  base  retired       runtime-22.2-py3.10
# spss-modeler_18.2              687eddc9-028a-4117-b9dd-e57b36f1efa5  base  not_provided
# pytorch-onnx_1.2-py3.6         692a6a4d-2c4d-45ff-a1ed-b167ee55469a  base  retired       runtime-22.2-py3.10
# spark-mllib_2.3-scala_2.11     7963efe5-bbec-417e-92cf-0574e21b4e8d  base  retired
# spark-mllib_2.4-py37           7abc992b-b685-532b-a122-a396a3cdbaab  base  retired       spark-mllib_3.3
# caffe_1.0-py3.6                7bb3dbe2-da6e-4145-918d-b6d84aa93b6b  base  retired
# pytorch-onnx_1.7-py3.7         812c6631-42b7-5613-982b-02098e6c909c  base  retired       pytorch-onnx_rt22.2-py3.10
# cuda-py3.6                     82c79ece-4d12-40e6-8787-a7b9e0f62770  base  retired
# tensorflow_1.15-py3.6-horovod  8964680e-d5e4-5bb8-919b-8342c6c0dfd8  base  retired
# hybrid_0.1                     8c1a58c6-62b5-4dc4-987a-df751c2756b6  base  not_provided
# pytorch-onnx_1.3-py3.7         8d5d8a87-a912-54cf-81ec-3914adaa988d  base  retired       pytorch-onnx_rt22.2-py3.10
# caffe-ibm_1.0-py3.6            8d863266-7927-4d1e-97d7-56a7f4c0a19b  base  retired
# runtime-22.2-py3.10-cuda       8ef391e4-ef58-5d46-b078-a82c211c1058  base  supported
# spss-modeler_17.1              902d0051-84bd-4af6-ab6b-8f6aa6fdeabb  base  not_provided
# do_12.10                       9100fd72-8159-4eb9-8a0b-a87e12eefa36  base  supported     do_20.1
# do_py3.7                       9447fa8b-2051-4d24-9eef-5acb0e3c59f8  base  retired
# spark-mllib_3.0-r_3.6          94bb6052-c837-589d-83f1-f4142f219e32  base  retired
# cuda-py3.7-opence              94e9652b-7f2d-59d5-ba5a-23a414ea488f  base  retired
# nlp-py3.8                      96e60351-99d4-5a1c-9cc0-473ac1b5a864  base  retired
# kernel-spark3.4-r4.2           9979f055-703f-5737-b9ca-679772a2e8dc  base  not_provided
# cuda-py3.7                     9a44990c-1aa1-4c7d-baf8-c4099011741c  base  retired
# hybrid_0.2                     9b3f9040-9cee-4ead-8d7a-780600f542f7  base  not_provided
# spark-mllib_3.0-py38           9f7a8fc1-4d3c-5e65-ab90-41fa8de2d418  base  retired       spark-mllib_3.3
# runtime-23.1-r4.2              a1275ec7-2602-52bd-a193-44ba137265df  base  supported
# autoai-tsad_rt22.2-py3.10      a1380ce0-5d3c-59ca-9b44-d6bf0739838a  base  supported     autoai-tsad_rt23.1-py3.10
# autoai-kb_3.3-py3.7            a545cca3-02df-5c61-9e88-998b09dc79af  base  retired       autoai-kb_rt22.2-py3.10
# spark-mllib_3.0-py39           a6082a27-5acc-5163-b02c-6b96916eb5e0  base  retired       spark-mllib_3.3
# runtime-22.1-py3.9-do          a7e7dbf1-1d03-5544-994d-e5ec845ce99a  base  retired
# default_py3.8                  ab9e1b80-f2ce-592c-a7d2-4f2344f77194  base  retired       runtime-22.2-py3.10
# tensorflow_rt22.1-py3.9        acd9c798-6974-5d2f-a657-ce06e986df4d  base  retired       tensorflow_rt22.2-py3.10
# kernel-spark3.2-py3.9          ad7033ee-794e-58cf-812e-a95f4b64b207  base  retired
# autoai-obm_2.0 with Spark 3.0  af10f35f-69fa-5d66-9bf5-acb58434263a  base  retired       autoai-obm_3.2
# runtime-23.1-py3.10-xc         b1a3e58f-ff58-59d7-8dc5-62042e42a538  base  not_provided
# autoai-kb_rt23.1-py3.10        b4246d87-d8b3-5621-9fea-76a8ea452616  base  supported
# runtime-22.2-py3.10            b56101f1-309d-549b-a849-eaa63f77b2fb  base  supported     runtime-23.1-py3.10
# default_py3.7_opence           c2057dd4-f42c-5f77-a02f-72bdbd3282c9  base  retired       runtime-22.2-py3.10
# tensorflow_2.1-py3.7           c4032338-2a40-500a-beef-b01ab2667e27  base  retired       runtime-22.2-py3.10
# do_py3.7_opence                cc8f8976-b74a-551a-bb66-6377f8d865b4  base  retired
# autoai-tsad_rt23.1-py3.10      cd3c730f-bc13-594f-9510-002634662e8b  base  supported
# spark-mllib_3.3                d11f2434-4fc7-58b7-8a62-755da64fdaf8  base  supported
# autoai-kb_3.0-py3.6            d139f196-e04b-5d8b-9140-9a10ca1fa91a  base  retired       autoai-kb_rt22.2-py3.10
# -----------------------------  ------------------------------------  ----  ------------  --------------------------
#                           NAME                                    ID  TYPE  \
# 0                default_py3.6  0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base
# 1      autoai-ts_rt23.1-py3.10  01ce9391-1a79-5a33-94fb-2e134337f314  base
# 2    kernel-spark3.2-scala2.12  020d69ce-7ac1-5e68-ac1a-31189867356a  base
# 3   pytorch-onnx_1.3-py3.7-edt  069ea134-3346-5748-b513-49120e15d288  base
# 4     tensorflow_rt23.1-py3.10  079a91e0-245f-5269-8926-3c20b28f37dc  base
# ..                         ...                                   ...   ...
# 95        tensorflow_2.1-py3.7  c4032338-2a40-500a-beef-b01ab2667e27  base
# 96             do_py3.7_opence  cc8f8976-b74a-551a-bb66-6377f8d865b4  base
# 97   autoai-tsad_rt23.1-py3.10  cd3c730f-bc13-594f-9510-002634662e8b  base
# 98             spark-mllib_3.3  d11f2434-4fc7-58b7-8a62-755da64fdaf8  base
# 99         autoai-kb_3.0-py3.6  d139f196-e04b-5d8b-9140-9a10ca1fa91a  base
#
#         STATE              REPLACEMENT
# 0     retired      runtime-22.2-py3.10
# 1   supported
# 2     retired
# 3     retired
# 4   supported
# ..        ...                      ...
# 95    retired      runtime-22.2-py3.10
# 96    retired
# 97  supported
# 98  supported
# 99    retired  autoai-kb_rt22.2-py3.10
#
# [100 rows x 5 columns]

# %%
software_space_uid=client.software_specifications.get_uid_by_name("tensorflow_rt22.2-py3.10")
software_space_uid
# Out:
# 'f65bd165-f057-55de-b5cb-f97cf2c0f393'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.12.0'

# %%
model_details = client.repository.store_model(model='image-classification-model_new.tgz',meta_props={
    client.repository.ModelMetaNames.NAME:"Image processing and model building",
    client.repository.ModelMetaNames.TYPE:"tensorflow_2.9",
    client.repository.ModelMetaNames.SOFTWARE_SPEC_UID:software_space_uid}
                                            )
model_id = client.repository.get_model_uid(model_details)
# Out:
# This method is deprecated, please use get_model_id()
# /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages/ibm_watson_machine_learning/repository.py:603: UserWarning: This method is deprecated, please use get_model_id()
#   warn("This method is deprecated, please use get_model_id()")

# %%
model_id
# Out:
# '7d67da12-d498-4046-8bd7-ce6df2c7c08c'

# %%
client.repository.download(model_id,'model.tar.gb')
# Out:
# Successfully saved model content to file: 'model.tar.gb'
# '/home/wsuser/work/kaggle/preprocessed dataset/preprocessed dataset/model.tar.gb'
